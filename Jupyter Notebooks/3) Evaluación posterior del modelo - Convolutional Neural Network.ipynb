# %% [markdown]
# # Entrenamiento y evaluación del modelo: Segunda parte

# %% [markdown]
# Para la segunda parte, se hará uso de una red neuronal convolucional. La idea central es ver si la accuracy del modelo puede mejorar un poco. Para esto, se tendrán que realizar ciertos ajustes al modelo.

# %% [markdown]
# En mi modelo anterior, se alcanzaron los siguientes valores de Accuracy:
#
# - Training Data Accuracy: 92%
# - Testing Data Accuracy: 87%

# %% [markdown]
# ### Leo la data preprocesada

# %%
# %store -r x_train
# %store -r y_train
# %store -r x_test
# %store -r y_test
# %store -r yy
# %store -r label_encoder

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Al estar trabajando con una CNN, voy a necesitar que mis inputs sean todos del mismo tamaño. Previamente, los vectores que obtenía luego del análisis de los MFCC variaban en sus dimensiones en función de la duración de los ejemplos.
#
# Para dejar todos mis inputs con las mismas longitudes, utilizo zero-padding.

# %%
import numpy as np
import pandas as pd
import os
import librosa


max_pad_len = 174

# Vuelvo a definir mi función para extraer features, pero utilizando mi zero padding a 174 como máximo.

def extract_features (file_name):
    # En primer lugar, voy a testear un resampleo kaiser_fast para que sea mas rapido
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs = librosa.feature.mfcc(y = audio, sr = sample_rate, n_mfcc = 40)
    
    # Agrego ceros hasta la longitud deseada
    pad_width = max_pad_len - mfccs.shape[1]
    mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    
    return mfccs

# %% [markdown]
# Nuevamente, leo mi dataset y extraigo los features ahora con zero padding,

# %%
# Defino el path absoluto donde estan localizados todos los audios

dataset_path = '/media/diego/4A64372E64371BDF/Downloads/Guitar Pro 5.2/UrbanSound8K/audio/'

# Leo la metadata 

metadata = pd.read_csv('../Jupyter Notebooks/Metadata/UrbanSound8K.csv')

# Preparo donde voy a colocar los features

features = []

# Itero a través de cada audio para obtener los nombres de los archivos y las clases

for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(dataset_path),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    class_label = row ["class_name"]
    
    # Extraigo los features para cada archivo
    
    data = extract_features (file_name)
    
    #Appendo en features []
    
    features.append([data, class_label])
    
# Convierto a un pandas dataframe

features_df = pd.DataFrame(features, columns=['features','class_label'])

# %% [markdown]
# Vuelvo a convertir mis datos de numerical a categorical

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convierto los features y sus correspondientes class_labels a numpy arrays

X = np.array (features_df.features.tolist())
y = np.array (features_df.class_label.tolist())

# Transformo las classification labels a numérico

label_encoder = LabelEncoder()

# Convierto el vector y (donde tengo las class_labels) a una matriz de clases binarias (0s y 1s).
# Con label_encoder las transformo a enteros, y con to_categorical paso esos enteros a la matriz binaria.

yy = to_categorical(label_encoder.fit_transform(y))
# Out:
# /home/diego/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Vuelvo a splitear mi dataset

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Convolutional Neural Network (CNN)

# %% [markdown]
# En esta etapa, voy a migrar de un modelo basado en un MLP a una Red Neuronal Convolucional (CNN).

# %% [markdown]
# Voy a utilizar nuevamente un modelo de tipo _sequential_. Inicialmente, este modelo contará con 4 capas de convolución (Conv2D). La última capa (output layer) será _densa_.
#
# Las capas de convolución tienen como objetivo la _detección de features_. La forma en la que trabaja es a partir de la operación básica de __convolución__ aplicada a una señal de 2 dimensiones (en este caso, las imágenes); es un proceso sencillo en el cual se desliza una ventana o filtro (antes de esto se invierte la misma) a través de todo el input, para luego realizar una multiplicación matricial y guardar los outputs en un __feature map__. Generalmente, en audio esta operación se realiza por sobre la señal temporal (considerada 1D).
#
# El parámetro _filter_ especifica el número de nodos en cada capa. Cada capa va a incrementarse en tamaño desde 16, 32, 64 a 128 mientras el parámetro _kernel size_ determina el tamaño de la ventana o filtro (denominado __kernel window__). En este caso, este parámetro es 2, resultando en una ventana o filtro de dimensión 2x2.
#
# La primera capa va a recibir mis inputs, que tienen una forma de (40, 174, 1) siendo 40 el número de MFCCs calculado, 174 el número de frames total teniendo en cuenta el zero padding realizado y 1 indicando que el audio es mono.
#
# La capa de salida va a tener 10 nodos (correspondientes a los 10 labels y a las 10 posibles clasificaciones). La función de activación para la capa de salida es la misma que en el ejemplo anterior (softmax).

# %% [markdown]
# ### Función de activación

# %% [markdown]
# Como función de activación para mis primeras 2 capas se utilizará __ReLU__ o Rectified Linear Activation, al igual que en el caso anterior. En lugar de utilizar un dropout del 50%, esta vez se utilizará un dropout menor (20%).

# %% [markdown]
# ### Pooling

# %% [markdown]
# Las __pooling layers__ se utilizan para reducir la dimensionalidad de mi modelo (a partir de reducir ciertos parámetros). Las mismas ayudan a disminuir el tiempo de entrenamiento y también el posible overfitting que pueda existir.
#
# Uno de los tipos de pooling layers que más se utiliza es el __Max Pooling__, que toma el tamaño máximo para cada ventana o patch de mi feature map, es decir, devuelve el valor máximo de la porción de imagen cubierta por el kernel. Otro tipo es __Average Pooling__, que devuelve justamente el promedio de la porción de imagen cubierta por el kernel.
#
# Cada capa convolucional tiene asociada una _pooling layer_ del tipo _MaxPooling2D_, mientras que la capa convolucional final va a tener asociada una pooling layer del tipo _GlobalAveragePooling2D_.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics

# Defino la forma de mis inputs

num_rows = 40
num_columns = 174
num_channels = 1

# Reshapeo utilizando los parámetros previamente definidos de zero padding

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)


num_labels = yy.shape[1]
filter_size = 2

# Construyo mi modelo secuencial capa por capa

model = Sequential()

# Construyo mi primer capa de inputs
model.add (Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add (MaxPooling2D(pool_size=2))
model.add (Dropout(0.2))

# Construyo mi siguiente capa
model.add (Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add (MaxPooling2D(pool_size=2))
model.add (Dropout (0.2))

# Construyo mi siguiente capa
model.add (Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add (MaxPooling2D(pool_size=2))
model.add (Dropout (0.2))

# Construyo mi siguiente capa
model.add (Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add (MaxPooling2D(pool_size=2))
model.add (Dropout(0.2))
model.add (GlobalAveragePooling2D())

# Construyo mi capa de outputs
model.add(Dense(num_labels, activation='softmax'))

# %% [markdown]
# ### Compilación del modelo

# %% [markdown]
# Para compilar el modelo, voy a utilizar los mismos 3 parámetros que utilicé en el ejemplo anterior (Categorical Cross-Entropy, Accuracy como métrica y Adam como optimizer).

# %%
# Compilo el modelo con los parámetros mencionados

model.compile (loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')

# %%
# Muestro un resumen de lo que sería la arquitectura que estoy usando

model.summary ()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 173, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 20, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 19, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 9, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 9, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1290
# =================================================================
# Total params: 44,602
# Trainable params: 44,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Calculo mi Accuracy antes del entrenamiento (pre-training accuracy)

score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Pre-training accuracy: 9.6737%

# %% [markdown]
# ## Entrenamiento del modelo

# %% [markdown]
# En esta sección, se iniciará con el entrenamiento de mi modelo. Debido a que el entrenamiento de una red neuronal puede tomar bastante tiempo, se utilizarán inicialmente 10 epochs, que se refieren justamente a la cantidad de veces que mi modelo va a iterar por mi data. De esta manera, el modelo intentará mejorar en cada iteración, hasta alcanzar un cierto objetivo. Además, inicialmente se utilizará un batch size bajo también. Si se observa que el modelo comienza a converger, se incrementarán ambos parámetros.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

number_epochs = 72

# Voy a dividir mi dataset en batchs de 128 samples
#batchsize = 128
batchsize = 256


# Con checkpoint puedo guardar el modelo o sus pesos en un determinado punto o intervalo.
checkpointer = ModelCheckpoint (filepath = '/home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5', verbose = 1,
                               save_best_only = True)

# Empiezo a contabilizar el tiempo para ver cuánto va a tardar en entrenar
start = datetime.now()

# Entreno mi modelo con los parámetros elegidos por un determinado número de epochs o iteraciones en mi dataset. 

model.fit(x_train, y_train, batch_size = batchsize, epochs = number_epochs, validation_data = (x_test, y_test), 
          callbacks = [checkpointer], verbose = 1)

# Veo cuánto tardó en entrenar
duration = datetime.now() - start

print ("Entrenamiento completado en: ", duration)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 3.5766 - accuracy: 0.1670
# Epoch 00001: val_loss improved from inf to 2.02712, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 77s 11ms/sample - loss: 3.5603 - accuracy: 0.1691 - val_loss: 2.0271 - val_accuracy: 0.2885
# Epoch 2/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.9129 - accuracy: 0.3105 - ETA: 10s - loss: 1.9571 -
# Epoch 00002: val_loss improved from 2.02712 to 1.82297, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 34s 5ms/sample - loss: 1.9104 - accuracy: 0.3112 - val_loss: 1.8230 - val_accuracy: 0.3698
# Epoch 3/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.6468 - accuracy: 0.4084
# Epoch 00003: val_loss improved from 1.82297 to 1.66813, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 32s 5ms/sample - loss: 1.6460 - accuracy: 0.4083 - val_loss: 1.6681 - val_accuracy: 0.4276
# Epoch 4/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.4594 - accuracy: 0.4728
# Epoch 00004: val_loss improved from 1.66813 to 1.50920, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 35s 5ms/sample - loss: 1.4598 - accuracy: 0.4724 - val_loss: 1.5092 - val_accuracy: 0.4843
# Epoch 5/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.3298 - accuracy: 0.5226
# Epoch 00005: val_loss improved from 1.50920 to 1.42037, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 1.3291 - accuracy: 0.5224 - val_loss: 1.4204 - val_accuracy: 0.5094
# Epoch 6/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.2370 - accuracy: 0.5589
# Epoch 00006: val_loss improved from 1.42037 to 1.31970, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 1.2378 - accuracy: 0.5593 - val_loss: 1.3197 - val_accuracy: 0.5444
# Epoch 7/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.1715 - accuracy: 0.5838
# Epoch 00007: val_loss improved from 1.31970 to 1.29659, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 1.1708 - accuracy: 0.5848 - val_loss: 1.2966 - val_accuracy: 0.5627
# Epoch 8/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.1217 - accuracy: 0.6056
# Epoch 00008: val_loss improved from 1.29659 to 1.23978, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 1.1227 - accuracy: 0.6060 - val_loss: 1.2398 - val_accuracy: 0.5678
# Epoch 9/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.0584 - accuracy: 0.6387
# Epoch 00009: val_loss improved from 1.23978 to 1.16453, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 1.0570 - accuracy: 0.6394 - val_loss: 1.1645 - val_accuracy: 0.6142
# Epoch 10/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 1.0199 - accuracy: 0.6489
# Epoch 00010: val_loss improved from 1.16453 to 1.16272, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 1.0174 - accuracy: 0.6501 - val_loss: 1.1627 - val_accuracy: 0.6113
# Epoch 11/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.9704 - accuracy: 0.6646
# Epoch 00011: val_loss improved from 1.16272 to 1.09357, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.9685 - accuracy: 0.6651 - val_loss: 1.0936 - val_accuracy: 0.6331
# Epoch 12/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.9259 - accuracy: 0.6797
# Epoch 00012: val_loss improved from 1.09357 to 1.02327, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.9287 - accuracy: 0.6792 - val_loss: 1.0233 - val_accuracy: 0.6737
# Epoch 13/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.8905 - accuracy: 0.6920
# Epoch 00013: val_loss improved from 1.02327 to 1.01444, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.8901 - accuracy: 0.6921 - val_loss: 1.0144 - val_accuracy: 0.6600
# Epoch 14/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.8641 - accuracy: 0.7017
# Epoch 00014: val_loss improved from 1.01444 to 0.96511, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 0.8664 - accuracy: 0.7011 - val_loss: 0.9651 - val_accuracy: 0.6886
# Epoch 15/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.8383 - accuracy: 0.7070
# Epoch 00015: val_loss improved from 0.96511 to 0.93367, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.8391 - accuracy: 0.7074 - val_loss: 0.9337 - val_accuracy: 0.6880
# Epoch 16/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.8094 - accuracy: 0.7221
# Epoch 00016: val_loss improved from 0.93367 to 0.90381, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.8077 - accuracy: 0.7224 - val_loss: 0.9038 - val_accuracy: 0.7001
# Epoch 17/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.7885 - accuracy: 0.7245
# Epoch 00017: val_loss improved from 0.90381 to 0.86764, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.7885 - accuracy: 0.7251 - val_loss: 0.8676 - val_accuracy: 0.7230
# Epoch 18/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.7676 - accuracy: 0.7399
# Epoch 00018: val_loss improved from 0.86764 to 0.83081, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.7697 - accuracy: 0.7390 - val_loss: 0.8308 - val_accuracy: 0.7367
# Epoch 19/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.7417 - accuracy: 0.7454
# Epoch 00019: val_loss improved from 0.83081 to 0.81329, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.7413 - accuracy: 0.7456 - val_loss: 0.8133 - val_accuracy: 0.7338
# Epoch 20/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.7159 - accuracy: 0.7585
# Epoch 00020: val_loss improved from 0.81329 to 0.80917, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.7164 - accuracy: 0.7582 - val_loss: 0.8092 - val_accuracy: 0.7373
# Epoch 21/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6846 - accuracy: 0.7717
# Epoch 00021: val_loss improved from 0.80917 to 0.72419, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.6831 - accuracy: 0.7724 - val_loss: 0.7242 - val_accuracy: 0.7693
# Epoch 22/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6653 - accuracy: 0.7718
# Epoch 00022: val_loss did not improve from 0.72419
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.6660 - accuracy: 0.7714 - val_loss: 0.7370 - val_accuracy: 0.7728
# Epoch 23/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6361 - accuracy: 0.7849
# Epoch 00023: val_loss did not improve from 0.72419
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.6342 - accuracy: 0.7854 - val_loss: 0.7245 - val_accuracy: 0.7705
# Epoch 24/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6273 - accuracy: 0.7840
# Epoch 00024: val_loss improved from 0.72419 to 0.67168, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 37s 5ms/sample - loss: 0.6268 - accuracy: 0.7840 - val_loss: 0.6717 - val_accuracy: 0.7962
# Epoch 25/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6068 - accuracy: 0.7970
# Epoch 00025: val_loss improved from 0.67168 to 0.62961, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.6055 - accuracy: 0.7974 - val_loss: 0.6296 - val_accuracy: 0.8008
# Epoch 26/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.6078 - accuracy: 0.7918
# Epoch 00026: val_loss did not improve from 0.62961
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.6078 - accuracy: 0.7917 - val_loss: 0.6560 - val_accuracy: 0.7790
# Epoch 27/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5817 - accuracy: 0.8070
# Epoch 00027: val_loss improved from 0.62961 to 0.59802, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.5824 - accuracy: 0.8067 - val_loss: 0.5980 - val_accuracy: 0.8122
# Epoch 28/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5657 - accuracy: 0.8111
# Epoch 00028: val_loss improved from 0.59802 to 0.59797, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.5662 - accuracy: 0.8110 - val_loss: 0.5980 - val_accuracy: 0.8071
# Epoch 29/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5642 - accuracy: 0.8087
# Epoch 00029: val_loss improved from 0.59797 to 0.59523, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.5632 - accuracy: 0.8090 - val_loss: 0.5952 - val_accuracy: 0.8168
# Epoch 30/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5305 - accuracy: 0.8244
# Epoch 00030: val_loss improved from 0.59523 to 0.56171, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.5318 - accuracy: 0.8233 - val_loss: 0.5617 - val_accuracy: 0.8277
# Epoch 31/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5230 - accuracy: 0.8232
# Epoch 00031: val_loss did not improve from 0.56171
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.5218 - accuracy: 0.8229 - val_loss: 0.5804 - val_accuracy: 0.8122
# Epoch 32/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5316 - accuracy: 0.8218
# Epoch 00032: val_loss improved from 0.56171 to 0.54559, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.5333 - accuracy: 0.8206 - val_loss: 0.5456 - val_accuracy: 0.8260
# Epoch 33/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.5174 - accuracy: 0.8254
# Epoch 00033: val_loss did not improve from 0.54559
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 0.5165 - accuracy: 0.8259 - val_loss: 0.5564 - val_accuracy: 0.8237
# Epoch 34/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.8391
# Epoch 00034: val_loss improved from 0.54559 to 0.52333, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.4866 - accuracy: 0.8382 - val_loss: 0.5233 - val_accuracy: 0.8340
# Epoch 35/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.8287
# Epoch 00035: val_loss did not improve from 0.52333
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.4944 - accuracy: 0.8299 - val_loss: 0.5421 - val_accuracy: 0.8214
# Epoch 36/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4796 - accuracy: 0.8406
# Epoch 00036: val_loss improved from 0.52333 to 0.51588, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.4805 - accuracy: 0.8399 - val_loss: 0.5159 - val_accuracy: 0.8363
# Epoch 37/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4627 - accuracy: 0.8417
# Epoch 00037: val_loss did not improve from 0.51588
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 0.4622 - accuracy: 0.8418 - val_loss: 0.5381 - val_accuracy: 0.8260
# Epoch 38/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4636 - accuracy: 0.8416
# Epoch 00038: val_loss improved from 0.51588 to 0.48085, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.4621 - accuracy: 0.8421 - val_loss: 0.4808 - val_accuracy: 0.8506
# Epoch 39/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4361 - accuracy: 0.8533
# Epoch 00039: val_loss did not improve from 0.48085
# 6985/6985 [==============================] - 44s 6ms/sample - loss: 0.4358 - accuracy: 0.8525 - val_loss: 0.5040 - val_accuracy: 0.8432
# Epoch 40/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4375 - accuracy: 0.8542
# Epoch 00040: val_loss improved from 0.48085 to 0.46756, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.4382 - accuracy: 0.8543 - val_loss: 0.4676 - val_accuracy: 0.8540
# Epoch 41/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4320 - accuracy: 0.8579
# Epoch 00041: val_loss improved from 0.46756 to 0.45592, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.4321 - accuracy: 0.8581 - val_loss: 0.4559 - val_accuracy: 0.8443
# Epoch 42/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4286 - accuracy: 0.8529
# Epoch 00042: val_loss did not improve from 0.45592
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.4281 - accuracy: 0.8531 - val_loss: 0.4879 - val_accuracy: 0.8495
# Epoch 43/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.4043 - accuracy: 0.8683
# Epoch 00043: val_loss improved from 0.45592 to 0.43629, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 38s 5ms/sample - loss: 0.4027 - accuracy: 0.8687 - val_loss: 0.4363 - val_accuracy: 0.8615
# Epoch 44/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3974 - accuracy: 0.8666
# Epoch 00044: val_loss did not improve from 0.43629
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.4006 - accuracy: 0.8651 - val_loss: 0.4528 - val_accuracy: 0.8580
# Epoch 45/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3888 - accuracy: 0.8641
# Epoch 00045: val_loss did not improve from 0.43629
# 6985/6985 [==============================] - 37s 5ms/sample - loss: 0.3881 - accuracy: 0.8643 - val_loss: 0.4376 - val_accuracy: 0.8592
# Epoch 46/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3857 - accuracy: 0.8704
# Epoch 00046: val_loss did not improve from 0.43629
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.3880 - accuracy: 0.8694 - val_loss: 0.4559 - val_accuracy: 0.8558
# Epoch 47/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.8688
# Epoch 00047: val_loss improved from 0.43629 to 0.40114, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 44s 6ms/sample - loss: 0.3953 - accuracy: 0.8689 - val_loss: 0.4011 - val_accuracy: 0.8724
# Epoch 48/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3581 - accuracy: 0.8746
# Epoch 00048: val_loss did not improve from 0.40114
# 6985/6985 [==============================] - 37s 5ms/sample - loss: 0.3594 - accuracy: 0.8743 - val_loss: 0.4600 - val_accuracy: 0.8466
# Epoch 49/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3857 - accuracy: 0.8681
# Epoch 00049: val_loss did not improve from 0.40114
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.3845 - accuracy: 0.8687 - val_loss: 0.4052 - val_accuracy: 0.8701
# Epoch 50/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3596 - accuracy: 0.8776
# Epoch 00050: val_loss improved from 0.40114 to 0.39455, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.3601 - accuracy: 0.8772 - val_loss: 0.3945 - val_accuracy: 0.8706
# Epoch 51/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3474 - accuracy: 0.8825
# Epoch 00051: val_loss did not improve from 0.39455
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.3469 - accuracy: 0.8823 - val_loss: 0.4145 - val_accuracy: 0.8718
# Epoch 52/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3480 - accuracy: 0.8805
# Epoch 00052: val_loss did not improve from 0.39455
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3501 - accuracy: 0.8799 - val_loss: 0.4074 - val_accuracy: 0.8689
# Epoch 53/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8805
# Epoch 00053: val_loss improved from 0.39455 to 0.37944, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3537 - accuracy: 0.8797 - val_loss: 0.3794 - val_accuracy: 0.8786
# Epoch 54/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8817
# Epoch 00054: val_loss did not improve from 0.37944
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3301 - accuracy: 0.8822 - val_loss: 0.3889 - val_accuracy: 0.8689
# Epoch 55/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3245 - accuracy: 0.8851
# Epoch 00055: val_loss did not improve from 0.37944
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.3241 - accuracy: 0.8852 - val_loss: 0.4092 - val_accuracy: 0.8764
# Epoch 56/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3372 - accuracy: 0.8834
# Epoch 00056: val_loss did not improve from 0.37944
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3364 - accuracy: 0.8836 - val_loss: 0.3817 - val_accuracy: 0.8775
# Epoch 57/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3145 - accuracy: 0.8909
# Epoch 00057: val_loss improved from 0.37944 to 0.37924, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.3168 - accuracy: 0.8901 - val_loss: 0.3792 - val_accuracy: 0.8746
# Epoch 58/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3084 - accuracy: 0.8945
# Epoch 00058: val_loss did not improve from 0.37924
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3071 - accuracy: 0.8949 - val_loss: 0.3799 - val_accuracy: 0.8672
# Epoch 59/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3119 - accuracy: 0.8919
# Epoch 00059: val_loss did not improve from 0.37924
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.3120 - accuracy: 0.8915 - val_loss: 0.3837 - val_accuracy: 0.8815
# Epoch 60/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3210 - accuracy: 0.8899
# Epoch 00060: val_loss improved from 0.37924 to 0.36309, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 42s 6ms/sample - loss: 0.3207 - accuracy: 0.8902 - val_loss: 0.3631 - val_accuracy: 0.8895
# Epoch 61/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.3082 - accuracy: 0.8931
# Epoch 00061: val_loss did not improve from 0.36309
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.3082 - accuracy: 0.8932 - val_loss: 0.3755 - val_accuracy: 0.8792
# Epoch 62/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2941 - accuracy: 0.9009
# Epoch 00062: val_loss did not improve from 0.36309
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2926 - accuracy: 0.9012 - val_loss: 0.3744 - val_accuracy: 0.8792
# Epoch 63/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2875 - accuracy: 0.9018
# Epoch 00063: val_loss improved from 0.36309 to 0.35739, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2875 - accuracy: 0.9015 - val_loss: 0.3574 - val_accuracy: 0.8890
# Epoch 64/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2849 - accuracy: 0.9006
# Epoch 00064: val_loss improved from 0.35739 to 0.35162, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.2846 - accuracy: 0.9006 - val_loss: 0.3516 - val_accuracy: 0.8918
# Epoch 65/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.9013
# Epoch 00065: val_loss did not improve from 0.35162
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2838 - accuracy: 0.9004 - val_loss: 0.3579 - val_accuracy: 0.8786
# Epoch 66/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2777 - accuracy: 0.9060
# Epoch 00066: val_loss improved from 0.35162 to 0.34691, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2791 - accuracy: 0.9057 - val_loss: 0.3469 - val_accuracy: 0.8895
# Epoch 67/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.9032
# Epoch 00067: val_loss improved from 0.34691 to 0.34511, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 40s 6ms/sample - loss: 0.2802 - accuracy: 0.9026 - val_loss: 0.3451 - val_accuracy: 0.8890
# Epoch 68/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2818 - accuracy: 0.9036
# Epoch 00068: val_loss did not improve from 0.34511
# 6985/6985 [==============================] - 39s 6ms/sample - loss: 0.2817 - accuracy: 0.9039 - val_loss: 0.3471 - val_accuracy: 0.8947
# Epoch 69/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2662 - accuracy: 0.9117
# Epoch 00069: val_loss did not improve from 0.34511
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.2657 - accuracy: 0.9118 - val_loss: 0.3522 - val_accuracy: 0.8970
# Epoch 70/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2772 - accuracy: 0.9049
# Epoch 00070: val_loss improved from 0.34511 to 0.33365, saving model to /home/diego/ML/Urban Sounds/Jupyter Notebooks/models/weights.best.basic_cnn.hdf5
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2770 - accuracy: 0.9048 - val_loss: 0.3337 - val_accuracy: 0.8947
# Epoch 71/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2566 - accuracy: 0.9109
# Epoch 00071: val_loss did not improve from 0.33365
# 6985/6985 [==============================] - 43s 6ms/sample - loss: 0.2559 - accuracy: 0.9111 - val_loss: 0.3456 - val_accuracy: 0.8918
# Epoch 72/72
# 6912/6985 [============================>.] - ETA: 0s - loss: 0.2489 - accuracy: 0.9119
# Epoch 00072: val_loss did not improve from 0.33365
# 6985/6985 [==============================] - 41s 6ms/sample - loss: 0.2488 - accuracy: 0.9120 - val_loss: 0.3593 - val_accuracy: 0.8867
# ('Entrenamiento completado en: ', datetime.timedelta(0, 2957, 26482))

# %%
print (duration)
# Out:
# 0:49:17.026482

# %% [markdown]
# ## Testeo del modelo

# %% [markdown]
# Voy a chequear la Accuracy de mi modelo, tanto para mi train set como para mi test set

# %%
# Evalúo mi modelo en mi training dataset

score_train = model.evaluate (x_train, y_train, verbose = 0)
print ("Training Accuracy: ", score_train [1])

# Evalúo mi modelo en mi testing dataset

score_test = model.evaluate (x_test, y_test, verbose = 0)
print ("Testing Accuracy: ", score_test [1])
# Out:
# ('Training Accuracy: ', 0.94230497)
# ('Testing Accuracy: ', 0.88666284)

# %% [markdown]
# Veo que mis valores de Accuracy mejoraron un poco (ambas incrementaron un 2%).

# %% [markdown]
# ## Predicciones

# %% [markdown]
# Voy a generar predicciones de una manera similar al notebook anterior.

# %%
# Defino una función para hacer predicciones sobre mis audios

def print_prediction (file_name):
    
    prediction_feature = extract_features(file_name)
    
    # Agrego el reshape que estuve trabajando
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)
    
    # Genero predicciones de clases para mis inputs
    predicted_vector = model.predict_classes(prediction_feature)
    
    # Transformo mis labels a mi original encoding
    predicted_class = label_encoder.inverse_transform (predicted_vector)
    
    print("The predicted class is:", predicted_class[0], '\n')
    
    
    # Determino las predicciones de probabilidad de las clases
    predicted_proba_vector = model.predict_proba(prediction_feature)
    predicted_proba = predicted_proba_vector[0]
    
    for i in range (len(predicted_proba)):
        category = label_encoder.inverse_transform(np.array([i]))
        print (category [0], "\t\t : ", format(predicted_proba[i], '.32f'))

# %% [markdown]
# ## Validación del modelo

# %% [markdown]
# Hago una chequeo inicial para verificar las predicciones utilizando un subset de archivos de audio que se trabajaron en el primer notebook. Se espera que estos sean clasificados correctamente.

# %% [markdown]
# #### 1) Car Horn

# %%
filename = '../Jupyter Notebooks/Audio Samples/24074-1-0-4.wav' 
print_prediction(filename)
# Out:
# ('The predicted class is:', 'car_horn', '\n')
# ('air_conditioner', '\t\t : ', '0.00000000000000000145999859657447')
# ('car_horn', '\t\t : ', '1.00000000000000000000000000000000')
# ('children_playing', '\t\t : ', '0.00000000000000000035057211999583')
# ('dog_bark', '\t\t : ', '0.00000000000000000030254198112552')
# ('drilling', '\t\t : ', '0.00000000000000068416333457387533')
# ('engine_idling', '\t\t : ', '0.00000000000002424382275609173604')
# ('gun_shot', '\t\t : ', '0.00000000000000000000000006576691')
# ('jackhammer', '\t\t : ', '0.00000000000000000000000872431567')
# ('siren', '\t\t : ', '0.00000000000000000320699722604641')
# ('street_music', '\t\t : ', '0.00000000013211343130592467787210')

# %% [markdown]
# #### 2) Dog Bark

# %%
filename = '../Jupyter Notebooks/Audio Samples/31323-3-0-22.wav' 
print_prediction(filename)
# Out:
# ('The predicted class is:', 'dog_bark', '\n')
# ('air_conditioner', '\t\t : ', '0.00000000000002514234514214373079')
# ('car_horn', '\t\t : ', '0.00000000000000733597024408583556')
# ('children_playing', '\t\t : ', '0.00001585400605108588933944702148')
# ('dog_bark', '\t\t : ', '0.99998414516448974609375000000000')
# ('drilling', '\t\t : ', '0.00000000000000013945926314465145')
# ('engine_idling', '\t\t : ', '0.00000000000000227230013573180047')
# ('gun_shot', '\t\t : ', '0.00000000000000000000123792001338')
# ('jackhammer', '\t\t : ', '0.00000000000000000000058858333350')
# ('siren', '\t\t : ', '0.00000000011985931691604889692826')
# ('street_music', '\t\t : ', '0.00000000757157625486115648527630')

# %% [markdown]
# #### 3) Drilling

# %%
filename = '../Jupyter Notebooks/Audio Samples/22962-4-0-1.wav'
print_prediction(filename)
# Out:
# ('The predicted class is:', 'car_horn', '\n')
# ('air_conditioner', '\t\t : ', '0.00197819457389414310455322265625')
# ('car_horn', '\t\t : ', '0.37578153610229492187500000000000')
# ('children_playing', '\t\t : ', '0.02147117629647254943847656250000')
# ('dog_bark', '\t\t : ', '0.03258474543690681457519531250000')
# ('drilling', '\t\t : ', '0.16188611090183258056640625000000')
# ('engine_idling', '\t\t : ', '0.06561945378780364990234375000000')
# ('gun_shot', '\t\t : ', '0.00102362781763076782226562500000')
# ('jackhammer', '\t\t : ', '0.03988300263881683349609375000000')
# ('siren', '\t\t : ', '0.03907153010368347167968750000000')
# ('street_music', '\t\t : ', '0.26070058345794677734375000000000')

# %% [markdown]
# Nuevamente, tengo una clasificación errónea de drilling, pero esta vez como Car Horn con 37% confidence (algo que no es completamente errado, ya que subjetivamente se percibe una bocina de auto en el audio), mientras que dirlling tiene 16%.

# %%
import IPython.display as ipd
ipd.Audio ('../Jupyter Notebooks/Audio Samples/22962-4-0-1.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 4) Gun Shot

# %%
filename = '../Jupyter Notebooks/Audio Samples/7061-6-0-0.wav'
print_prediction (filename)
# Out:
# ('The predicted class is:', 'gun_shot', '\n')
# ('air_conditioner', '\t\t : ', '0.00000000753281437226860361988656')
# ('car_horn', '\t\t : ', '0.00021852747886441648006439208984')
# ('children_playing', '\t\t : ', '0.00707544060423970222473144531250')
# ('dog_bark', '\t\t : ', '0.00552344368770718574523925781250')
# ('drilling', '\t\t : ', '0.00412965891882777214050292968750')
# ('engine_idling', '\t\t : ', '0.00269497954286634922027587890625')
# ('gun_shot', '\t\t : ', '0.97539174556732177734375000000000')
# ('jackhammer', '\t\t : ', '0.00000216900502891803625971078873')
# ('siren', '\t\t : ', '0.00495122047141194343566894531250')
# ('street_music', '\t\t : ', '0.00001270401662623044103384017944')

# %% [markdown]
# ### B) Testeo con audio externo a mis datasets

# %%
filename = '../Jupyter Notebooks/Audio Samples/dog_bark_1.wav'
print_prediction (filename)
# Out:
# ('The predicted class is:', 'dog_bark', '\n')
# ('air_conditioner', '\t\t : ', '0.00305432779714465141296386718750')
# ('car_horn', '\t\t : ', '0.01427096407860517501831054687500')
# ('children_playing', '\t\t : ', '0.02974716015160083770751953125000')
# ('dog_bark', '\t\t : ', '0.78981500864028930664062500000000')
# ('drilling', '\t\t : ', '0.11488822847604751586914062500000')
# ('engine_idling', '\t\t : ', '0.00201808963902294635772705078125')
# ('gun_shot', '\t\t : ', '0.02794492244720458984375000000000')
# ('jackhammer', '\t\t : ', '0.00055961654288694262504577636719')
# ('siren', '\t\t : ', '0.01143030729144811630249023437500')
# ('street_music', '\t\t : ', '0.00627130083739757537841796875000')

# %%
filename = '../Jupyter Notebooks/Audio Samples/gun_shot_1.wav'
print_prediction (filename)
# Out:
# ('The predicted class is:', 'gun_shot', '\n')
# ('air_conditioner', '\t\t : ', '0.00001394213268213206902146339417')
# ('car_horn', '\t\t : ', '0.00000235012475968687795102596283')
# ('children_playing', '\t\t : ', '0.00039504290907643735408782958984')
# ('dog_bark', '\t\t : ', '0.02331313490867614746093750000000')
# ('drilling', '\t\t : ', '0.00773297203704714775085449218750')
# ('engine_idling', '\t\t : ', '0.00035392274730838835239410400391')
# ('gun_shot', '\t\t : ', '0.96803992986679077148437500000000')
# ('jackhammer', '\t\t : ', '0.00000288943488158110994845628738')
# ('siren', '\t\t : ', '0.00009567827510181814432144165039')
# ('street_music', '\t\t : ', '0.00005015299393562600016593933105')

# %%
filename = '../Jupyter Notebooks/Audio Samples/drilling_1.wav'
print_prediction (filename)
# Out:
# ('The predicted class is:', 'jackhammer', '\n')
# ('air_conditioner', '\t\t : ', '0.00237056822516024112701416015625')
# ('car_horn', '\t\t : ', '0.00015262495435308665037155151367')
# ('children_playing', '\t\t : ', '0.00125818606466054916381835937500')
# ('dog_bark', '\t\t : ', '0.00067948264768347144126892089844')
# ('drilling', '\t\t : ', '0.00738029554486274719238281250000')
# ('engine_idling', '\t\t : ', '0.02585771866142749786376953125000')
# ('gun_shot', '\t\t : ', '0.00000154002532326558139175176620')
# ('jackhammer', '\t\t : ', '0.96132397651672363281250000000000')
# ('siren', '\t\t : ', '0.00020062497060280293226242065430')
# ('street_music', '\t\t : ', '0.00077503360807895660400390625000')

# %% [markdown]
# Aparentemente, el modelo performea de manera bastante satisfactoria, generaliza correctamente y predice bien contra data nueva (más allá de que predice drilling como jackhammer que son muy parecidos en espectro). En el próximo paso, se llevará a cabo una segunda versión de este proyecto, cambiando ciertos parámetros de preprocesamiento (modificando los valores de resampleo, cantidad de MFCCs, profundidad de bits) y ciertos parámetros de la CNN (nodos en cada capa, dropout, etc.)
